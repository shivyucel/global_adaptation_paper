# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from scipy.stats import ttest_ind
import numpy as np
from scipy.stats.stats import pearsonr
from IPython.display import display, Markdown, Latex
plt.style.use('ggplot')
from datetime import date
data_path = '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/'
from scipy.stats import norm
from sklearn.cluster import KMeans
import numpy as np
import pandas
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_2485/1898700607.py:8: DeprecationWarning: Please import `pearsonr` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.stats.stats import pearsonr

# %%
#load mobility and temperature data
#load heatwave - control dataframe
mobility_heat = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/paper2/nigeria/THI_mobility_heat_clean_90.csv')
heatwave_control = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/paper2/nigeria/THI_heatwave_control_90.csv')

# %%
heatwave_control['datetime'].min()
# Out:
# '2022-02-18'

# %% [markdown]
# ## Build Intensity Variable

# %%
full_df = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/THI/nigeria/daily_max_THI.csv')

full_df.rename(columns={'time': 'datetime'}, inplace=True)
full_df['datetime'] = pd.to_datetime(full_df['datetime'])
full_df['day'] = pd.DatetimeIndex(full_df['datetime']).day
full_df['month'] = pd.DatetimeIndex(full_df['datetime']).month
full_df['year'] = pd.DatetimeIndex(full_df['datetime']).year
full_df.month.unique()
full_df = full_df[~full_df['month'].isin([5])]

full_df['location'] = full_df['adm2'] + ', ' + full_df['adm1']
full_df['datetime_ord'] = [date(x,y,z).toordinal() for x,y,z in zip(full_df['year'], full_df['month'], full_df['day'])]

# %%
mobility_heat['control_day'] = pd.to_datetime(mobility_heat['control_day'])

# %%
#merge temperatures from control day onto mobility heat
mobility_heat = mobility_heat.merge(full_df[['datetime', 'thi', 'location']], left_on=['location', 'control_day'], right_on=['location', 'datetime'], suffixes=('_heat', '_control'))

# %%
(mobility_heat['thi_heat'] - mobility_heat['thi_control']).max()
# Out:
# np.float64(9.575853771633568)

# %%
np.corrcoef(mobility_heat['thi_heat'], mobility_heat['thi_control'])
# Out:
# array([[1.        , 0.67823988],
#        [0.67823988, 1.        ]])

# %% [markdown]
# ### Create/explore temperature difference variable

# %%
mobility_heat['temp_diff'] = mobility_heat['thi_heat'] - mobility_heat['thi_control']

# %%
mobility_heat['temp_diff'].describe()
# Out:
# count    1488.000000
# mean        3.364445
# std         1.758996
# min         0.790854
# 25%         2.010302
# 50%         2.886812
# 75%         4.424974
# max         9.575854
# Name: temp_diff, dtype: float64

# %%
sns.histplot(mobility_heat, x='temp_diff')
plt.title("Temperature Difference (heat wave vs. control)")
plt.tight_layout()
plt.savefig(data_path + '/img/12_09_2023/india_temp_diff_dist.png')

# %% [markdown]
# ### Build Duration Variable
# * Duration of heat wave (in days)
# * Build variable showing which day of a heatwave it is

# %%
# Formatting column names and merging dataframes

# %%
heatwave_control.sort_values(by='Heat Wave Duration', inplace=True)

# %%
duration_IDs = heatwave_control.drop_duplicates('heat_ID')[['heat_ID', 'Heat Wave Duration']  ]

# %%
duration_IDs.columns = ['heat_ID', 'Heat Wave Duration']

# %%
duration_IDs.head()
# Out:
#                                    heat_ID  Heat Wave Duration
# 0     5c5f5670-5a05-4cac-a495-22e15d5e3cb2                 2.0
# 4353  dc7ee9b4-2c0d-4b86-bb66-4adbdfbd6969                 2.0
# 4351  942679c7-27da-4691-9985-7ffb4a4977d0                 2.0
# 4349  191350d7-42b7-4aa3-abf1-7f0d7c3726a8                 2.0
# 4345  c33fe6cb-cd7c-4043-9256-d8aa495da992                 2.0

# %%
duration_IDs['Heat Wave Duration'].describe()
# Out:
# count    2275.000000
# mean        4.041758
# std         2.815730
# min         2.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        15.000000
# Name: Heat Wave Duration, dtype: float64

# %%
#drop original heatwave duration variable
heatwave_control.drop('Heat Wave Duration', axis=1, inplace=True)

# %%
#merge duration ID dataframe onto heatwave control
heatwave_control = heatwave_control.merge(duration_IDs, on='heat_ID', how='left')

# %%
heatwave_control.drop_duplicates(['location', 'datetime'], inplace=True)

# %%
heatwave_control['dur_ranking'] = heatwave_control['Heat Wave Duration'].rank(pct=True)

# %%
#groupby each heatwave, sort by date, assign increasing rank for each passing day
heat_stage = heatwave_control.groupby('heat_ID').apply(lambda x: x.datetime.sort_values().rank()).reset_index()
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_2485/111197883.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   heat_stage = heatwave_control.groupby('heat_ID').apply(lambda x: x.datetime.sort_values().rank()).reset_index()

# %%
heat_stage.columns=['heat_ID', 'index', 'stage']

# %%
heat_stage['stage'].max()
# Out:
# np.float64(15.0)

# %%
x = heat_stage.merge(duration_IDs, on='heat_ID')

# %%
heatwave_control.drop('index', axis=1, inplace=True)

# %%
heatwave_control.reset_index(inplace=True)

# %%
heatwave_control = heatwave_control.merge(heat_stage, on=['index', 'heat_ID'])

# %%
heatwave_control['datetime'] = pd.to_datetime(heatwave_control['datetime'])

# %%
heatwave_control['stage'].max()
# Out:
# np.float64(15.0)

# %%
mobility_heat['date_heat'] = pd.to_datetime(mobility_heat['date_heat'])

# %%
#merge temporal variables into mobility_heat

mobility_heat = mobility_heat.merge(heatwave_control[['location', 'datetime', 'Heat Wave Duration', 'dur_ranking', 'stage']], left_on=['location', 'date_heat'], right_on=['location', 'datetime'])

# %%
mobility_heat.reset_index(inplace=True)

# %%
mobility_heat['month'] = [x.month for x in mobility_heat['datetime']]

# %%
mobility_heat['month'].unique()
# Out:
# array([3, 4, 2])

# %%
#sorts heatwaves together
unique_IDs = heatwave_control.drop_duplicates('heat_ID')
unique_IDs = unique_IDs[['heat_ID']]

mobility_heat = mobility_heat.merge(unique_IDs, on='heat_ID')

# %%
# format final variables
mobility_heat['stage_frac'] = (mobility_heat['stage'] / mobility_heat['Heat Wave Duration'] )
mobility_heat.drop_duplicates('heat_ID')['Heat Wave Duration'].describe()
# Out:
# count    463.000000
# mean       3.444924
# std        2.249745
# min        2.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max       12.000000
# Name: Heat Wave Duration, dtype: float64

# %%
mobility_heat['heatwave_dur'] = mobility_heat['Heat Wave Duration'] >= 4

# %%
mobility_heat['month'] = [x.month for x in pd.to_datetime(mobility_heat['date_control'])]

# %%
mobility_heat['date_control'] = pd.to_datetime(mobility_heat['date_control'])

# %%
mobility_heat['date_control']
# Out:
# 0      2022-02-28
# 1      2022-02-22
# 2      2022-02-28
# 3      2022-02-22
# 4      2022-03-15
#           ...
# 1483   2022-03-31
# 1484   2022-03-31
# 1485   2022-03-25
# 1486   2022-04-15
# 1487   2022-04-18
# Name: date_control, Length: 1488, dtype: datetime64[ns]

# %% [markdown]
# ## Merge social and physical variables

# %%
soc_phys = gpd.read_file('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/physical/nigeria/merged_Global2.shp')

# %%
mobility_heat= mobility_heat.merge(soc_phys[['location', 'mean_elev', 'coast', 'HDI_dec', 'popden_dec', 'over60_dec']], on='location')

# %%
mobility_heat['elev_1500m'] = mobility_heat['mean_elev'] >= 1500

# %%
mobility_heat['elev_1500m'] = mobility_heat['elev_1500m'] * 1

# %% [markdown]
# ### Remove holidays

# %%
import requests

# %%
hols_2021 = pd.DataFrame(requests.get("https://date.nager.at/api/v3/publicholidays/2021/NG").json())
hols_2022 = pd.DataFrame(requests.get("https://date.nager.at/api/v3/publicholidays/2022/NG").json())
hols = pd.concat([hols_2021, hols_2022])
hols['date'] = pd.to_datetime(hols['date'])

# %%
mobility_heat = mobility_heat[~mobility_heat['datetime_heat'].isin(hols['date'].values)]
mobility_heat = mobility_heat[~mobility_heat['datetime_control'].isin(hols['date'].values)]

# %% [markdown]
# ## Normalized rain variable for heatwave and control day

# %%
precip = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/precipitation/nigeria/daily_sum_precipitation.csv')
precip.rename(columns={'valid_time': 'time'}, inplace=True)
precip['time'] = pd.to_datetime(precip['time'])

# %%
gdf = gpd.read_file('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/adm0_shp/nigeria/clean_shp.shp')
gdf['location'] = gdf['adm2'] + ', ' + gdf['adm1']
gdf.to_crs(epsg='3857', inplace=True)
gdf['area'] = [x.area for x in gdf['geometry']]

# %%
#area from m --> km
#rain from m --> mm
precip['daily_precipitation'] = precip['daily_precipitation'] * 1000
gdf['area'] = gdf['area'] / 1000

# %%
precip = precip.merge(gdf[['location', 'area']], on='location')
precip['rain_normed'] = (precip['daily_precipitation'] / precip['area'])

# %%
precip['rain_standard'] = precip.groupby('location')['rain_normed'].rank(pct=True) * 100

# %% [markdown]
# ### Control day rain dummy

# %%
mobility_heat = mobility_heat.merge(precip[['time', 'adm1', 'adm2', 'rain_standard']], left_on=['control_day', 'adm1', 'adm2'], right_on=['time', 'adm1', 'adm2'])

# %%
mobility_heat.rename(columns={'rain_standard': "rain_standard_control"}, inplace=True)

# %% [markdown]
# ### Heatwave day rain dummy

# %%
mobility_heat = mobility_heat.merge(precip[['time', 'adm1', 'adm2', 'rain_standard']], left_on=['date_heat', 'adm1', 'adm2'], right_on=['time', 'adm1', 'adm2'])

# %%
mobility_heat.rename(columns={'rain_standard': "rain_standard_heat"}, inplace=True)

# %% [markdown]
# ### Prepare final dataset

# %%
df = mobility_heat.copy()

# %%
df = df[df['mean_elev'] <= 2500]

# %%
df
# Out:
#       index  Unnamed: 0.1  Unnamed: 0 country_region_code country_region  \
# 0         0             0         641                  NG        Nigeria
# 1         1             1         642                  NG        Nigeria
# 2         2             2         929                  NG        Nigeria
# 3         3             3         930                  NG        Nigeria
# 4         4             4         951                  NG        Nigeria
# ...     ...           ...         ...                 ...            ...
# 1447   1481          1481       55162                  NG        Nigeria
# 1448   1482          1482       55157                  NG        Nigeria
# 1449   1483          1483       55163                  NG        Nigeria
# 1450   1484          1484       55168                  NG        Nigeria
# 1451   1485          1485       55158                  NG        Nigeria
#
#          adm1       adm2  metro_area  iso_3166_2_code  census_fips_code  ...  \
# 0        Abia  Aba North         NaN              NaN               NaN  ...
# 1        Abia  Aba North         NaN              NaN               NaN  ...
# 2        Abia  Aba South         NaN              NaN               NaN  ...
# 3        Abia  Aba South         NaN              NaN               NaN  ...
# 4        Abia  Aba South         NaN              NaN               NaN  ...
# ...       ...        ...         ...              ...               ...  ...
# 1447  Zamfara      Gusau         NaN              NaN               NaN  ...
# 1448  Zamfara      Gusau         NaN              NaN               NaN  ...
# 1449  Zamfara      Gusau         NaN              NaN               NaN  ...
# 1450  Zamfara      Gusau         NaN              NaN               NaN  ...
# 1451  Zamfara      Gusau         NaN              NaN               NaN  ...
#
#        mean_elev coast  HDI_dec  popden_dec  over60_dec  elev_1500m  \
# 0      58.500000     0        8          10           7           0
# 1      58.500000     0        8          10           7           0
# 2      57.000000     0        8          10           7           0
# 3      57.000000     0        8          10           7           0
# 4      57.000000     0        8          10           7           0
# ...          ...   ...      ...         ...         ...         ...
# 1447  539.685723     0        2           6           3           0
# 1448  539.685723     0        2           6           3           0
# 1449  539.685723     0        2           6           3           0
# 1450  539.685723     0        2           6           3           0
# 1451  539.685723     0        2           6           3           0
#
#          time_x  rain_standard_control     time_y rain_standard_heat
# 0    2022-02-28              41.208791 2022-03-07          70.329670
# 1    2022-02-22              10.439560 2022-03-08          72.527473
# 2    2022-02-28              36.813187 2022-03-07          61.538462
# 3    2022-02-22              10.989011 2022-03-08          69.780220
# 4    2022-03-15              70.879121 2022-03-29          54.395604
# ...         ...                    ...        ...                ...
# 1447 2022-03-30               7.967033 2022-04-13          95.604396
# 1448 2022-03-31               7.967033 2022-04-07          84.615385
# 1449 2022-03-31               7.967033 2022-04-14          96.153846
# 1450 2022-03-31               7.967033 2022-04-21          97.802198
# 1451 2022-03-25              86.813187 2022-04-08          19.780220
#
# [1452 rows x 58 columns]

# %%
#set outlier cutoff (how many SDs away from mean)
SD = 4

# %%
df.columns
# Out:
# Index(['index', 'Unnamed: 0.1', 'Unnamed: 0', 'country_region_code',
#        'country_region', 'adm1', 'adm2', 'metro_area', 'iso_3166_2_code',
#        'census_fips_code', 'place_id', 'date_heat', 'retail_rec_heat',
#        'grocery_pharm_heat', 'parks_heat', 'transit_heat', 'workplaces_heat',
#        'residential_heat', 'location', 'control_day', 'thi_heat',
#        'datetime_heat', 'heat_ID', 'date_control', 'retail_rec_control',
#        'grocery_pharm_control', 'parks_control', 'transit_control',
#        'workplaces_control', 'residential_control', 'retail_rec_difference',
#        'grocery_pharm_difference', 'parks_difference', 'transit_difference',
#        'workplaces_difference', 'residential_difference', 'day_of_week',
#        'weekend', 'datetime_control', 'thi_control', 'temp_diff', 'datetime',
#        'Heat Wave Duration', 'dur_ranking', 'stage', 'month', 'stage_frac',
#        'heatwave_dur', 'mean_elev', 'coast', 'HDI_dec', 'popden_dec',
#        'over60_dec', 'elev_1500m', 'time_x', 'rain_standard_control', 'time_y',
#        'rain_standard_heat'],
#       dtype='object')

# %%
for variable in ['workplaces_difference', 'residential_difference', 'grocery_pharm_difference', 'parks_difference', 'retail_rec_difference', 'transit_difference']:
    df[variable] = [np.nan if (x >= df[variable].mean() + (SD * df[variable].std())) | (x <= df[variable].mean() - (SD * df[variable].std())) else x for x in df[variable] ]

    #v13
df.dropna(how='all', subset=['workplaces_difference', 'residential_difference', 'transit_difference', 'parks_difference', 'grocery_pharm_difference', 'retail_rec_difference'], inplace=True)

# %%
df = df.iloc[:, 3:]

# %%
df[['residential_difference', 'workplaces_difference', 'transit_difference', 'grocery_pharm_difference', 'retail_rec_difference', 'parks_difference']].describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#                            count      mean        std    min    max
# residential_difference     624.0  4.399038   4.132563   -5.0   20.0
# workplaces_difference     1388.0  2.293948  15.517929  -64.0   72.0
# transit_difference         450.0  4.317778  24.852687  -74.0   92.0
# grocery_pharm_difference   416.0 -2.379808  15.403332  -49.0   53.0
# retail_rec_difference      358.0  0.748603  19.275198  -55.0   74.0
# parks_difference           282.0 -0.535461  25.355981 -100.0  103.0

# %%
df
# Out:
#      country_region_code country_region     adm1       adm2  metro_area  \
# 0                     NG        Nigeria     Abia  Aba North         NaN
# 1                     NG        Nigeria     Abia  Aba North         NaN
# 2                     NG        Nigeria     Abia  Aba South         NaN
# 3                     NG        Nigeria     Abia  Aba South         NaN
# 4                     NG        Nigeria     Abia  Aba South         NaN
# ...                  ...            ...      ...        ...         ...
# 1447                  NG        Nigeria  Zamfara      Gusau         NaN
# 1448                  NG        Nigeria  Zamfara      Gusau         NaN
# 1449                  NG        Nigeria  Zamfara      Gusau         NaN
# 1450                  NG        Nigeria  Zamfara      Gusau         NaN
# 1451                  NG        Nigeria  Zamfara      Gusau         NaN
#
#       iso_3166_2_code  census_fips_code                     place_id  \
# 0                 NaN               NaN  ChIJJ9SHpK2eQhARZRwKEePBcuk
# 1                 NaN               NaN  ChIJJ9SHpK2eQhARZRwKEePBcuk
# 2                 NaN               NaN  ChIJcXDuChycQhARUr8yL5GPm98
# 3                 NaN               NaN  ChIJcXDuChycQhARUr8yL5GPm98
# 4                 NaN               NaN  ChIJcXDuChycQhARUr8yL5GPm98
# ...               ...               ...                          ...
# 1447              NaN               NaN  ChIJlyUOw4XCsxERJi_qqjf8lzI
# 1448              NaN               NaN  ChIJlyUOw4XCsxERJi_qqjf8lzI
# 1449              NaN               NaN  ChIJlyUOw4XCsxERJi_qqjf8lzI
# 1450              NaN               NaN  ChIJlyUOw4XCsxERJi_qqjf8lzI
# 1451              NaN               NaN  ChIJlyUOw4XCsxERJi_qqjf8lzI
#
#       date_heat  retail_rec_heat  ...   mean_elev  coast  HDI_dec  popden_dec  \
# 0    2022-03-07              NaN  ...   58.500000      0        8          10
# 1    2022-03-08              NaN  ...   58.500000      0        8          10
# 2    2022-03-07            -37.0  ...   57.000000      0        8          10
# 3    2022-03-08             22.0  ...   57.000000      0        8          10
# 4    2022-03-29             36.0  ...   57.000000      0        8          10
# ...         ...              ...  ...         ...    ...      ...         ...
# 1447 2022-04-13              NaN  ...  539.685723      0        2           6
# 1448 2022-04-07              NaN  ...  539.685723      0        2           6
# 1449 2022-04-14              NaN  ...  539.685723      0        2           6
# 1450 2022-04-21              NaN  ...  539.685723      0        2           6
# 1451 2022-04-08              NaN  ...  539.685723      0        2           6
#
#       over60_dec elev_1500m     time_x  rain_standard_control     time_y  \
# 0              7          0 2022-02-28              41.208791 2022-03-07
# 1              7          0 2022-02-22              10.439560 2022-03-08
# 2              7          0 2022-02-28              36.813187 2022-03-07
# 3              7          0 2022-02-22              10.989011 2022-03-08
# 4              7          0 2022-03-15              70.879121 2022-03-29
# ...          ...        ...        ...                    ...        ...
# 1447           3          0 2022-03-30               7.967033 2022-04-13
# 1448           3          0 2022-03-31               7.967033 2022-04-07
# 1449           3          0 2022-03-31               7.967033 2022-04-14
# 1450           3          0 2022-03-31               7.967033 2022-04-21
# 1451           3          0 2022-03-25              86.813187 2022-04-08
#
#      rain_standard_heat
# 0             70.329670
# 1             72.527473
# 2             61.538462
# 3             69.780220
# 4             54.395604
# ...                 ...
# 1447          95.604396
# 1448          84.615385
# 1449          96.153846
# 1450          97.802198
# 1451          19.780220
#
# [1444 rows x 55 columns]

# %%
df.reset_index(inplace=True)

# %%
df.sort_values(by=['location', 'heat_ID', 'index'], inplace=True)

# %%
df.to_csv(f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/paper2/nigeria/THI_mobility_heat_w_vars_90_{SD}SD_precip_Global2.csv')

# %%
df= pd.read_csv(f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/paper2/nigeria/THI_mobility_heat_w_vars_90_{SD}SD_precip.csv')

# %%
ng = pd.read_csv(f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/paper2_repo/__clean/data/nigeria.csv')

# %%
df
# Out:
#       Unnamed: 0  index country_region_code country_region    adm1       adm2  \
# 0              0      0                  NG        Nigeria    Abia  Aba North
# 1              1      1                  NG        Nigeria    Abia  Aba North
# 2              4      4                  NG        Nigeria    Abia  Aba South
# 3              5      5                  NG        Nigeria    Abia  Aba South
# 4              6      6                  NG        Nigeria    Abia  Aba South
# ...          ...    ...                 ...            ...     ...        ...
# 1439         624    629                  NG        Nigeria  Kaduna      Zaria
# 1440         625    630                  NG        Nigeria  Kaduna      Zaria
# 1441         627    632                  NG        Nigeria  Kaduna      Zaria
# 1442         628    633                  NG        Nigeria  Kaduna      Zaria
# 1443         630    635                  NG        Nigeria  Kaduna      Zaria
#
#       metro_area  iso_3166_2_code  census_fips_code  \
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
# ...          ...              ...               ...
# 1439         NaN              NaN               NaN
# 1440         NaN              NaN               NaN
# 1441         NaN              NaN               NaN
# 1442         NaN              NaN               NaN
# 1443         NaN              NaN               NaN
#
#                          place_id  ...   mean_elev  coast  HDI_dec  \
# 0     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 1     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 2     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 3     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 4     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# ...                           ...  ...         ...    ...      ...
# 1439  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1440  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1441  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1442  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1443  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
#
#       popden_dec  over60_dec  elev_1500m      time_x rain_standard_control  \
# 0             10           7           0  2022-02-28             41.208791
# 1             10           7           0  2022-02-22             10.439560
# 2             10           5           0  2022-03-15             70.879121
# 3             10           5           0  2022-03-23             73.076923
# 4             10           5           0  2022-03-24             90.659341
# ...          ...         ...         ...         ...                   ...
# 1439           9           2           0  2022-03-30              7.967033
# 1440           9           2           0  2022-03-31              7.967033
# 1441           9           2           0  2022-03-25             84.615385
# 1442           9           2           0  2022-03-26             17.032967
# 1443           9           2           0  2022-03-27             25.000000
#
#           time_y  rain_standard_heat
# 0     2022-03-07           70.329670
# 1     2022-03-08           72.527473
# 2     2022-03-29           54.395604
# 3     2022-03-30           68.681319
# 4     2022-03-31           58.791209
# ...          ...                 ...
# 1439  2022-04-06           61.813187
# 1440  2022-04-07           82.417582
# 1441  2022-04-08           87.362637
# 1442  2022-04-09            7.967033
# 1443  2022-04-10           90.109890
#
# [1444 rows x 57 columns]

# %%
pd.concat([ng,df]).drop_duplicates(keep=False)
# Out:
#       Unnamed: 0  index country_region_code country_region    adm1       adm2  \
# 0              0      0                  NG        Nigeria    Abia  Aba North
# 1              1      1                  NG        Nigeria    Abia  Aba North
# 2              2      2                  NG        Nigeria    Abia  Aba South
# 3              3      3                  NG        Nigeria    Abia  Aba South
# 4              4      4                  NG        Nigeria    Abia  Aba South
# ...          ...    ...                 ...            ...     ...        ...
# 1439         624    629                  NG        Nigeria  Kaduna      Zaria
# 1440         625    630                  NG        Nigeria  Kaduna      Zaria
# 1441         627    632                  NG        Nigeria  Kaduna      Zaria
# 1442         628    633                  NG        Nigeria  Kaduna      Zaria
# 1443         630    635                  NG        Nigeria  Kaduna      Zaria
#
#       metro_area  iso_3166_2_code  census_fips_code  \
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
# ...          ...              ...               ...
# 1439         NaN              NaN               NaN
# 1440         NaN              NaN               NaN
# 1441         NaN              NaN               NaN
# 1442         NaN              NaN               NaN
# 1443         NaN              NaN               NaN
#
#                          place_id  ...   mean_elev  coast  HDI_dec  \
# 0     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 1     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 2     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 3     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 4     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# ...                           ...  ...         ...    ...      ...
# 1439  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1440  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1441  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1442  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1443  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
#
#       popden_dec  over60_dec  elev_1500m      time_x rain_standard_control  \
# 0             10           7           0  2022-02-28             41.208791
# 1             10           7           0  2022-02-22             10.439560
# 2             10           5           0  2022-02-28             36.813187
# 3             10           5           0  2022-02-22             10.989011
# 4             10           5           0  2022-03-15             70.879121
# ...          ...         ...         ...         ...                   ...
# 1439           9           2           0  2022-03-30              7.967033
# 1440           9           2           0  2022-03-31              7.967033
# 1441           9           2           0  2022-03-25             84.615385
# 1442           9           2           0  2022-03-26             17.032967
# 1443           9           2           0  2022-03-27             25.000000
#
#           time_y  rain_standard_heat
# 0     2022-03-07           70.329670
# 1     2022-03-08           72.527473
# 2     2022-03-07           61.538462
# 3     2022-03-08           69.780220
# 4     2022-03-29           54.395604
# ...          ...                 ...
# 1439  2022-04-06           61.813187
# 1440  2022-04-07           82.417582
# 1441  2022-04-08           87.362637
# 1442  2022-04-09            7.967033
# 1443  2022-04-10           90.109890
#
# [2888 rows x 59 columns]

# %%
pd.concat([df, ng]).drop_duplicates(keep=False)
# Out:
#       Unnamed: 0  index country_region_code country_region     adm1  \
# 0              0      0                  NG        Nigeria     Abia
# 1              1      1                  NG        Nigeria     Abia
# 2              4      4                  NG        Nigeria     Abia
# 3              5      5                  NG        Nigeria     Abia
# 4              6      6                  NG        Nigeria     Abia
# ...          ...    ...                 ...            ...      ...
# 1439        1439   1447                  NG        Nigeria  Zamfara
# 1440        1440   1448                  NG        Nigeria  Zamfara
# 1441        1441   1449                  NG        Nigeria  Zamfara
# 1442        1442   1450                  NG        Nigeria  Zamfara
# 1443        1443   1451                  NG        Nigeria  Zamfara
#
#            adm2  metro_area  iso_3166_2_code  census_fips_code  \
# 0     Aba North         NaN              NaN               NaN
# 1     Aba North         NaN              NaN               NaN
# 2     Aba South         NaN              NaN               NaN
# 3     Aba South         NaN              NaN               NaN
# 4     Aba South         NaN              NaN               NaN
# ...         ...         ...              ...               ...
# 1439      Gusau         NaN              NaN               NaN
# 1440      Gusau         NaN              NaN               NaN
# 1441      Gusau         NaN              NaN               NaN
# 1442      Gusau         NaN              NaN               NaN
# 1443      Gusau         NaN              NaN               NaN
#
#                          place_id  ... HDI_dec  popden_dec  over60_dec  \
# 0     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...       8          10           7
# 1     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...       8          10           7
# 2     ChIJcXDuChycQhARUr8yL5GPm98  ...       8          10           5
# 3     ChIJcXDuChycQhARUr8yL5GPm98  ...       8          10           5
# 4     ChIJcXDuChycQhARUr8yL5GPm98  ...       8          10           5
# ...                           ...  ...     ...         ...         ...
# 1439  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...       2           4           2
# 1440  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...       2           4           2
# 1441  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...       2           4           2
# 1442  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...       2           4           2
# 1443  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...       2           4           2
#
#       elev_1500m      time_x  rain_standard_control      time_y  \
# 0              0  2022-02-28              41.208791  2022-03-07
# 1              0  2022-02-22              10.439560  2022-03-08
# 2              0  2022-03-15              70.879121  2022-03-29
# 3              0  2022-03-23              73.076923  2022-03-30
# 4              0  2022-03-24              90.659341  2022-03-31
# ...          ...         ...                    ...         ...
# 1439           0  2022-03-30               7.967033  2022-04-13
# 1440           0  2022-03-31               7.967033  2022-04-07
# 1441           0  2022-03-31               7.967033  2022-04-14
# 1442           0  2022-03-31               7.967033  2022-04-21
# 1443           0  2022-03-25              86.813187  2022-04-08
#
#      rain_standard_heat    hw_pct  early_hw
# 0             70.329670       NaN       NaN
# 1             72.527473       NaN       NaN
# 2             54.395604       NaN       NaN
# 3             68.681319       NaN       NaN
# 4             58.791209       NaN       NaN
# ...                 ...       ...       ...
# 1439          95.604396  0.537143       0.0
# 1440          84.615385  0.537143       0.0
# 1441          96.153846  0.537143       0.0
# 1442          97.802198  0.876264       0.0
# 1443          19.780220  0.537143       0.0
#
# [2888 rows x 59 columns]

# %%
(ng.merge(df, how='outer', indicator=True)
    .loc[lambda d: d.pop('_merge').eq('right_only')]
 )
# Out:
#       Unnamed: 0  index country_region_code country_region    adm1       adm2  \
# 1444         324    327                  NG        Nigeria  Ebonyi  Abakaliki
# 1445         325    328                  NG        Nigeria  Ebonyi  Abakaliki
# 1446         322    325                  NG        Nigeria  Ebonyi  Abakaliki
# 1447         323    326                  NG        Nigeria  Ebonyi  Abakaliki
# 1448        1091   1098                  NG        Nigeria    Osun   Aiyedade
# ...          ...    ...                 ...            ...     ...        ...
# 1602         764    769                  NG        Nigeria    Kano    Tarauni
# 1603         781    786                  NG        Nigeria    Kano     Ungogo
# 1604         784    789                  NG        Nigeria    Kano     Ungogo
# 1605         782    787                  NG        Nigeria    Kano     Ungogo
# 1606         785    790                  NG        Nigeria    Kano     Ungogo
#
#       metro_area  iso_3166_2_code  census_fips_code  \
# 1444         NaN              NaN               NaN
# 1445         NaN              NaN               NaN
# 1446         NaN              NaN               NaN
# 1447         NaN              NaN               NaN
# 1448         NaN              NaN               NaN
# ...          ...              ...               ...
# 1602         NaN              NaN               NaN
# 1603         NaN              NaN               NaN
# 1604         NaN              NaN               NaN
# 1605         NaN              NaN               NaN
# 1606         NaN              NaN               NaN
#
#                          place_id  ...   mean_elev  coast  HDI_dec  \
# 1444  ChIJ5ylIygacXBAR8eiyRp6G1_Q  ...   49.351103      0        5
# 1445  ChIJ5ylIygacXBAR8eiyRp6G1_Q  ...   49.351103      0        5
# 1446  ChIJ5ylIygacXBAR8eiyRp6G1_Q  ...   49.351103      0        5
# 1447  ChIJ5ylIygacXBAR8eiyRp6G1_Q  ...   49.351103      0        5
# 1448  ChIJT3nCprm2ORARMhlPxdE4f7E  ...  199.125975      0        7
# ...                           ...  ...         ...    ...      ...
# 1602  ChIJB9QxbsaBrhERTWgDkdxcvgo  ...  480.258065      0        3
# 1603  ChIJo6J8QceGrhERNmxir243hO0  ...  467.956204      0        3
# 1604  ChIJo6J8QceGrhERNmxir243hO0  ...  467.956204      0        3
# 1605  ChIJo6J8QceGrhERNmxir243hO0  ...  467.956204      0        3
# 1606  ChIJo6J8QceGrhERNmxir243hO0  ...  467.956204      0        3
#
#       popden_dec  over60_dec  elev_1500m      time_x rain_standard_control  \
# 1444           7           3           0  2022-03-29             64.835165
# 1445           7           3           0  2022-03-30             35.714286
# 1446           7           3           0  2022-03-18             49.450549
# 1447           7           3           0  2022-03-26             19.780220
# 1448           4           9           0  2022-02-28             41.758242
# ...          ...         ...         ...         ...                   ...
# 1602          10           1           0  2022-03-27             27.472527
# 1603          10           1           0  2022-03-26             18.681319
# 1604          10           1           0  2022-03-27             27.472527
# 1605          10           1           0  2022-03-26             18.681319
# 1606          10           1           0  2022-03-27             27.472527
#
#           time_y  rain_standard_heat
# 1444  2022-04-05           59.340659
# 1445  2022-04-06           85.164835
# 1446  2022-04-01           85.714286
# 1447  2022-04-02           79.120879
# 1448  2022-03-07           62.087912
# ...          ...                 ...
# 1602  2022-04-17           57.692308
# 1603  2022-04-16           98.901099
# 1604  2022-04-17           58.791209
# 1605  2022-04-23           44.505495
# 1606  2022-04-24           17.582418
#
# [163 rows x 59 columns]

# %%
df[['residential_difference', 'workplaces_difference', 'transit_difference', 'grocery_pharm_difference', 'parks_difference', 'parks_difference', 'rain_standard_heat']].describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#                            count       mean        std         min         max
# residential_difference     624.0   4.399038   4.132563   -5.000000   20.000000
# workplaces_difference     1388.0   2.293948  15.517929  -64.000000   72.000000
# transit_difference         450.0   4.317778  24.852687  -74.000000   92.000000
# grocery_pharm_difference   416.0  -2.379808  15.403332  -49.000000   53.000000
# retail_rec_difference      358.0   0.748603  19.275198  -55.000000   74.000000
# parks_difference           282.0  -0.535461  25.355981 -100.000000  103.000000
# rain_standard_control     1444.0  43.014102  24.495801    0.549451   98.901099

# %%
ng[['index', 'residential_difference', 'workplaces_difference', 'transit_difference', 'grocery_pharm_difference', 'retail_rec_difference', 'transit_difference', 'rain_standard_heat', 'rain_standard_control',
'thi_heat', 'temp_diff', 'heatwave_dur', 'stage_frac', 'weekend', 'popden_dec', 'HDI_dec', 'over60_dec', 'elev_1500m', 'coast']].describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#                            count        mean         std        min  \
# index                     1444.0  726.502770  419.053472   0.000000
# residential_difference     624.0    4.399038    4.132563  -5.000000
# workplaces_difference     1388.0    2.293948   15.517929 -64.000000
# transit_difference         450.0    4.317778   24.852687 -74.000000
# grocery_pharm_difference   416.0   -2.379808   15.403332 -49.000000
# retail_rec_difference      358.0    0.748603   19.275198 -55.000000
# transit_difference         450.0    4.317778   24.852687 -74.000000
# rain_standard_heat        1444.0   72.806764   21.480770   0.549451
# rain_standard_control     1444.0   43.014102   24.495801   0.549451
# thi_heat                  1444.0   38.654468    1.601258  30.836104
# temp_diff                 1444.0    3.335934    1.751320   0.790854
# stage_frac                1444.0    0.646195    0.281742   0.083333
# weekend                   1444.0    0.171745    0.377289   0.000000
# popden_dec                1444.0    7.819252    2.576861   1.000000
# HDI_dec                   1444.0    6.271468    2.917387   1.000000
# over60_dec                1444.0    4.766620    3.367567   1.000000
# elev_1500m                1444.0    0.000000    0.000000   0.000000
# coast                     1444.0    0.024931    0.155968   0.000000
#
#                                   max
# index                     1451.000000
# residential_difference      20.000000
# workplaces_difference       72.000000
# transit_difference          92.000000
# grocery_pharm_difference    53.000000
# retail_rec_difference       74.000000
# transit_difference          92.000000
# rain_standard_heat         100.000000
# rain_standard_control       98.901099
# thi_heat                    42.386288
# temp_diff                    9.575854
# stage_frac                   1.000000
# weekend                      1.000000
# popden_dec                  10.000000
# HDI_dec                     10.000000
# over60_dec                  10.000000
# elev_1500m                   0.000000
# coast                        1.000000

# %%
df
# Out:
#       Unnamed: 0  index country_region_code country_region    adm1       adm2  \
# 0              0      0                  NG        Nigeria    Abia  Aba North
# 1              1      1                  NG        Nigeria    Abia  Aba North
# 2              4      4                  NG        Nigeria    Abia  Aba South
# 3              5      5                  NG        Nigeria    Abia  Aba South
# 4              6      6                  NG        Nigeria    Abia  Aba South
# ...          ...    ...                 ...            ...     ...        ...
# 1439         624    629                  NG        Nigeria  Kaduna      Zaria
# 1440         625    630                  NG        Nigeria  Kaduna      Zaria
# 1441         627    632                  NG        Nigeria  Kaduna      Zaria
# 1442         628    633                  NG        Nigeria  Kaduna      Zaria
# 1443         630    635                  NG        Nigeria  Kaduna      Zaria
#
#       metro_area  iso_3166_2_code  census_fips_code  \
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
# ...          ...              ...               ...
# 1439         NaN              NaN               NaN
# 1440         NaN              NaN               NaN
# 1441         NaN              NaN               NaN
# 1442         NaN              NaN               NaN
# 1443         NaN              NaN               NaN
#
#                          place_id  ...   mean_elev  coast  HDI_dec  \
# 0     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 1     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 2     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 3     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 4     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# ...                           ...  ...         ...    ...      ...
# 1439  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1440  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1441  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1442  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
# 1443  ChIJ_7yiNKScshERoSJKBIGnTmY  ...  646.865672      0        4
#
#       popden_dec  over60_dec  elev_1500m      time_x rain_standard_control  \
# 0             10           7           0  2022-02-28             41.208791
# 1             10           7           0  2022-02-22             10.439560
# 2             10           5           0  2022-03-15             70.879121
# 3             10           5           0  2022-03-23             73.076923
# 4             10           5           0  2022-03-24             90.659341
# ...          ...         ...         ...         ...                   ...
# 1439           9           2           0  2022-03-30              7.967033
# 1440           9           2           0  2022-03-31              7.967033
# 1441           9           2           0  2022-03-25             84.615385
# 1442           9           2           0  2022-03-26             17.032967
# 1443           9           2           0  2022-03-27             25.000000
#
#           time_y  rain_standard_heat
# 0     2022-03-07           70.329670
# 1     2022-03-08           72.527473
# 2     2022-03-29           54.395604
# 3     2022-03-30           68.681319
# 4     2022-03-31           58.791209
# ...          ...                 ...
# 1439  2022-04-06           61.813187
# 1440  2022-04-07           82.417582
# 1441  2022-04-08           87.362637
# 1442  2022-04-09            7.967033
# 1443  2022-04-10           90.109890
#
# [1444 rows x 57 columns]

# %%
ng
# Out:
#       Unnamed: 0  index country_region_code country_region     adm1  \
# 0              0      0                  NG        Nigeria     Abia
# 1              1      1                  NG        Nigeria     Abia
# 2              2      2                  NG        Nigeria     Abia
# 3              3      3                  NG        Nigeria     Abia
# 4              4      4                  NG        Nigeria     Abia
# ...          ...    ...                 ...            ...      ...
# 1439        1439   1447                  NG        Nigeria  Zamfara
# 1440        1440   1448                  NG        Nigeria  Zamfara
# 1441        1441   1449                  NG        Nigeria  Zamfara
# 1442        1442   1450                  NG        Nigeria  Zamfara
# 1443        1443   1451                  NG        Nigeria  Zamfara
#
#            adm2  metro_area  iso_3166_2_code  census_fips_code  \
# 0     Aba North         NaN              NaN               NaN
# 1     Aba North         NaN              NaN               NaN
# 2     Aba South         NaN              NaN               NaN
# 3     Aba South         NaN              NaN               NaN
# 4     Aba South         NaN              NaN               NaN
# ...         ...         ...              ...               ...
# 1439      Gusau         NaN              NaN               NaN
# 1440      Gusau         NaN              NaN               NaN
# 1441      Gusau         NaN              NaN               NaN
# 1442      Gusau         NaN              NaN               NaN
# 1443      Gusau         NaN              NaN               NaN
#
#                          place_id  ...   mean_elev  coast  HDI_dec  \
# 0     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 1     ChIJJ9SHpK2eQhARZRwKEePBcuk  ...   58.500000      0        8
# 2     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 3     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# 4     ChIJcXDuChycQhARUr8yL5GPm98  ...   57.000000      0        8
# ...                           ...  ...         ...    ...      ...
# 1439  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...  539.685723      0        2
# 1440  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...  539.685723      0        2
# 1441  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...  539.685723      0        2
# 1442  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...  539.685723      0        2
# 1443  ChIJlyUOw4XCsxERJi_qqjf8lzI  ...  539.685723      0        2
#
#       popden_dec  over60_dec  elev_1500m      time_x rain_standard_control  \
# 0             10           7           0  2022-02-28             41.208791
# 1             10           7           0  2022-02-22             10.439560
# 2             10           5           0  2022-02-28             36.813187
# 3             10           5           0  2022-02-22             10.989011
# 4             10           5           0  2022-03-15             70.879121
# ...          ...         ...         ...         ...                   ...
# 1439           4           2           0  2022-03-30              7.967033
# 1440           4           2           0  2022-03-31              7.967033
# 1441           4           2           0  2022-03-31              7.967033
# 1442           4           2           0  2022-03-31              7.967033
# 1443           4           2           0  2022-03-25             86.813187
#
#           time_y  rain_standard_heat
# 0     2022-03-07           70.329670
# 1     2022-03-08           72.527473
# 2     2022-03-07           61.538462
# 3     2022-03-08           69.780220
# 4     2022-03-29           54.395604
# ...          ...                 ...
# 1439  2022-04-13           95.604396
# 1440  2022-04-07           84.615385
# 1441  2022-04-14           96.153846
# 1442  2022-04-21           97.802198
# 1443  2022-04-08           19.780220
#
# [1444 rows x 59 columns]

# %%
df['index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ox/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/opt/anaconda3/envs/ox/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/ox/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[411], line 1
# ----> 1 df['index']
#
# File ~/opt/anaconda3/envs/ox/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/ox/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'index'

# %%
df[['index', 'residential_difference', 'workplaces_difference', 'transit_difference', 'grocery_pharm_difference', 'retail_rec_difference', 'transit_difference', 'rain_standard_heat', 'rain_standard_control',
'thi_heat', 'temp_diff', 'heatwave_dur', 'stage_frac', 'weekend', 'popden_dec', 'HDI_dec', 'over60_dec', 'elev_1500m', 'coast']].describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#                            count        mean         std        min  \
# index                     1444.0  726.503463  419.053212   0.000000
# residential_difference     624.0    4.399038    4.132563  -5.000000
# workplaces_difference     1388.0    2.293948   15.517929 -64.000000
# transit_difference         450.0    4.317778   24.852687 -74.000000
# grocery_pharm_difference   416.0   -2.379808   15.403332 -49.000000
# retail_rec_difference      358.0    0.748603   19.275198 -55.000000
# transit_difference         450.0    4.317778   24.852687 -74.000000
# rain_standard_heat        1444.0   72.806764   21.480770   0.549451
# rain_standard_control     1444.0   43.014102   24.495801   0.549451
# thi_heat                  1444.0   38.654468    1.601258  30.836104
# temp_diff                 1444.0    3.335934    1.751320   0.790854
# stage_frac                1444.0    0.646195    0.281742   0.083333
# weekend                   1444.0    0.171745    0.377289   0.000000
# popden_dec                1444.0    7.819252    2.576861   1.000000
# HDI_dec                   1444.0    6.271468    2.917387   1.000000
# over60_dec                1444.0    4.766620    3.367567   1.000000
# elev_1500m                1444.0    0.000000    0.000000   0.000000
# coast                     1444.0    0.024931    0.155968   0.000000
#
#                                   max
# index                     1451.000000
# residential_difference      20.000000
# workplaces_difference       72.000000
# transit_difference          92.000000
# grocery_pharm_difference    53.000000
# retail_rec_difference       74.000000
# transit_difference          92.000000
# rain_standard_heat         100.000000
# rain_standard_control       98.901099
# thi_heat                    42.386288
# temp_diff                    9.575854
# stage_frac                   1.000000
# weekend                      1.000000
# popden_dec                  10.000000
# HDI_dec                     10.000000
# over60_dec                  10.000000
# elev_1500m                   0.000000
# coast                        1.000000
